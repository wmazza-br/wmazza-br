# %% [markdown]
# #Aula Zero

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd

# %%
notas = pd.read_csv("ratings.csv")

notas.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
notas.shape
# Out:
# (100836, 4)

# %%
notas.columns = ["usuarioId", "filmeId", "nota", "momento"]
notas.head()
# Out:
#    usuarioId  filmeId  nota    momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %%
notas['nota']
# Out:
# 0         4.0
# 1         4.0
# 2         4.0
# 3         5.0
# 4         5.0
#          ...
# 100831    4.0
# 100832    5.0
# 100833    5.0
# 100834    5.0
# 100835    3.0
# Name: nota, Length: 100836, dtype: float64

# %%
notas['nota'].unique()
# Out:
# array([4. , 5. , 3. , 2. , 1. , 4.5, 3.5, 2.5, 0.5, 1.5])

# %%
notas['nota'].value_counts()
# Out:
# 4.0    26818
# 3.0    20047
# 5.0    13211
# 3.5    13136
# 4.5     8551
# 2.0     7551
# 2.5     5550
# 1.0     2811
# 1.5     1791
# 0.5     1370
# Name: nota, dtype: int64

# %%
notas['nota'].mean()
# Out:
# 3.501556983616962

# %%
notas.nota.plot()

# %%
notas.nota.plot(kind='hist')

# %%
print("Média",notas.nota.mean())
print("Mediana",notas.nota.median())
# Out:
# Média 3.501556983616962
# Mediana 3.5

# %%
notas.nota.describe()
# Out:
# count    100836.000000
# mean          3.501557
# std           1.042529
# min           0.500000
# 25%           3.000000
# 50%           3.500000
# 75%           4.000000
# max           5.000000
# Name: nota, dtype: float64

# %%
import seaborn as sns

sns.boxplot(notas.nota)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
pd.value_counts(notas.nota)
# Out:
# 4.0    26818
# 3.0    20047
# 5.0    13211
# 3.5    13136
# 4.5     8551
# 2.0     7551
# 2.5     5550
# 1.0     2811
# 1.5     1791
# 0.5     1370
# Name: nota, dtype: int64

# %%
notas.nota.value_counts()
# Out:
# 4.0    26818
# 3.0    20047
# 5.0    13211
# 3.5    13136
# 4.5     8551
# 2.0     7551
# 2.5     5550
# 1.0     2811
# 1.5     1791
# 0.5     1370
# Name: nota, dtype: int64

# %% [markdown]
# #Aula 1

# %%
import pandas as pd

filmes = pd.read_csv("movies.csv")

filmes.head()
# Out:
#    movieId  ...                                       genres
# 0        1  ...  Adventure|Animation|Children|Comedy|Fantasy
# 1        2  ...                   Adventure|Children|Fantasy
# 2        3  ...                               Comedy|Romance
# 3        4  ...                         Comedy|Drama|Romance
# 4        5  ...                                       Comedy
#
# [5 rows x 3 columns]

# %%
filmes.columns = ["filmeId", "titulo", "generos"]

filmes.head()
# Out:
#    filmeId  ...                                      generos
# 0        1  ...  Adventure|Animation|Children|Comedy|Fantasy
# 1        2  ...                   Adventure|Children|Fantasy
# 2        3  ...                               Comedy|Romance
# 3        4  ...                         Comedy|Drama|Romance
# 4        5  ...                                       Comedy
#
# [5 rows x 3 columns]

# %%
notas.query("filmeId==1").nota
# Out:
# 0        4.0
# 516      4.0
# 874      4.5
# 1434     2.5
# 1667     4.5
#         ...
# 97364    2.5
# 98479    4.0
# 98666    2.5
# 99497    3.0
# 99534    5.0
# Name: nota, Length: 215, dtype: float64

# %%
medias_por_filme = notas.groupby("filmeId").mean().nota
medias_por_filme.head()
# Out:
# filmeId
# 1    3.920930
# 2    3.431818
# 3    3.259615
# 4    2.357143
# 5    3.071429
# Name: nota, dtype: float64

# %%
medias_por_filme.plot(kind="hist")

# %%
sns.boxplot(medias_por_filme)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
medias_por_filme.describe()
# Out:
# count    9724.000000
# mean        3.262448
# std         0.869874
# min         0.500000
# 25%         2.800000
# 50%         3.416667
# 75%         3.911765
# max         5.000000
# Name: nota, dtype: float64

# %%
sns.distplot(medias_por_filme, bins=10)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import matplotlib.pyplot as plt

plt.hist(medias_por_filme)
# Out:
# (array([ 108.,  185.,  309.,  694.,  962., 1840., 2211., 2275.,  798.,
#          342.]),
#  array([0.5 , 0.95, 1.4 , 1.85, 2.3 , 2.75, 3.2 , 3.65, 4.1 , 4.55, 5.  ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(medias_por_filme)
plt.title("Histograma das médias dos filmes")
# Out:
# Text(0.5, 1.0, 'Histograma das médias dos filmes')

# %%
plt.figure(figsize=(5,10))

sns.boxplot(y=medias_por_filme)

# %%
sns.boxplot(notas.nota)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
notas.query("filmeId==1").nota.mean()

notas.query("filmeId==2").nota.mean()
# Out:
# 3.4318181818181817

# %% [markdown]
# #Data Visualization

# %%
tmdb = pd.read_csv("tmdb_5000_movies.csv")
tmdb.head()
# Out:
#       budget  ... vote_count
# 0  237000000  ...      11800
# 1  300000000  ...       4500
# 2  245000000  ...       4466
# 3  250000000  ...       9106
# 4  260000000  ...       2124
#
# [5 rows x 20 columns]

# %%
tmdb.original_language.unique()
# Out:
# array(['en', 'ja', 'fr', 'zh', 'es', 'de', 'hi', 'ru', 'ko', 'te', 'cn',
#        'it', 'nl', 'ta', 'sv', 'th', 'da', 'xx', 'hu', 'cs', 'pt', 'is',
#        'tr', 'nb', 'af', 'pl', 'he', 'ar', 'vi', 'ky', 'id', 'ro', 'fa',
#        'no', 'sl', 'ps', 'el'], dtype=object)

# %%
contagem_de_lingua = tmdb.original_language.value_counts().to_frame().reset_index()
contagem_de_lingua.columns = ["original_language", "total"]
contagem_de_lingua.head()
# Out:
#   original_language  total
# 0                en   4505
# 1                fr     70
# 2                es     32
# 3                zh     27
# 4                de     27

# %%
sns.barplot(x="original_language", y="total", data = contagem_de_lingua)

# %%
sns.catplot(x="original_language", kind="count", data=tmdb)

# %%
print(sns.__version__)
# Out:
# 0.11.2

# %%
plt.pie(contagem_de_lingua["total"], labels = contagem_de_lingua["original_language"])
# Out:
# ([<matplotlib.patches.Wedge at 0x7fce9f20d890>,
#   <matplotlib.patches.Wedge at 0x7fce9f20d610>,
#   <matplotlib.patches.Wedge at 0x7fce9f20db50>,
#   <matplotlib.patches.Wedge at 0x7fce9f252b50>,
#   <matplotlib.patches.Wedge at 0x7fce9f19b750>,
#   <matplotlib.patches.Wedge at 0x7fce9f19bd90>,
#   <matplotlib.patches.Wedge at 0x7fce9f1a80d0>,
#   <matplotlib.patches.Wedge at 0x7fce9f1a8190>,
#   <matplotlib.patches.Wedge at 0x7fce9f19b3d0>,
#   <matplotlib.patches.Wedge at 0x7fce9f1a8d10>,
#   <matplotlib.patches.Wedge at 0x7fce9f20d8d0>,
#   <matplotlib.patches.Wedge at 0x7fce9f1b5790>,
#   <matplotlib.patches.Wedge at 0x7fce9f144250>,
#   <matplotlib.patches.Wedge at 0x7fce9f144310>,
#   <matplotlib.patches.Wedge at 0x7fce9f1448d0>,
#   <matplotlib.patches.Wedge at 0x7fce9f14e3d0>,
#   <matplotlib.patches.Wedge at 0x7fce9f14e490>,
#   <matplotlib.patches.Wedge at 0x7fce9f14ea50>,
#   <matplotlib.patches.Wedge at 0x7fce9f15a050>,
#   <matplotlib.patches.Wedge at 0x7fce9f15a610>,
#   <matplotlib.patches.Wedge at 0x7fce9f164110>,
#   <matplotlib.patches.Wedge at 0x7fce9f1641d0>,
#   <matplotlib.patches.Wedge at 0x7fce9f164790>,
#   <matplotlib.patches.Wedge at 0x7fce9f170290>,
#   <matplotlib.patches.Wedge at 0x7fce9f170350>,
#   <matplotlib.patches.Wedge at 0x7fce9f170910>,
#   <matplotlib.patches.Wedge at 0x7fce9f0f9410>,
#   <matplotlib.patches.Wedge at 0x7fce9f0f94d0>,
#   <matplotlib.patches.Wedge at 0x7fce9f0f9a90>,
#   <matplotlib.patches.Wedge at 0x7fce9f107090>,
#   <matplotlib.patches.Wedge at 0x7fce9f107650>,
#   <matplotlib.patches.Wedge at 0x7fce9f111150>,
#   <matplotlib.patches.Wedge at 0x7fce9f111210>,
#   <matplotlib.patches.Wedge at 0x7fce9f1117d0>,
#   <matplotlib.patches.Wedge at 0x7fce9f11e2d0>,
#   <matplotlib.patches.Wedge at 0x7fce9f11e390>,
#   <matplotlib.patches.Wedge at 0x7fce9f11e950>],
#  [Text(-1.0791697536499925, 0.2130554923183512, 'en'),
#   Text(1.0355355017029462, -0.3710339940124459, 'fr'),
#   Text(1.0579676486019882, -0.3011718023181785, 'es'),
#   Text(1.0687996606645356, -0.26012936274741094, 'zh'),
#   Text(1.0773191105706255, -0.22222406260195313, 'de'),
#   Text(1.0835167978583342, -0.18971386021801853, 'hi'),
#   Text(1.0875756432724297, -0.16486121484618815, 'ja'),
#   Text(1.0906010773146022, -0.14348968659882622, 'it'),
#   Text(1.092883487371409, -0.12492270822755745, 'cn'),
#   Text(1.0946390911069936, -0.10846778425161549, 'ru'),
#   Text(1.0960865535188649, -0.09270527058984593, 'ko'),
#   Text(1.0972054830031333, -0.07835896928789601, 'pt'),
#   Text(1.097965443340663, -0.06687215586282344, 'da'),
#   Text(1.0984565010300316, -0.05825217030171998, 'sv'),
#   Text(1.0987803851616647, -0.0517847968421653, 'fa'),
#   Text(1.0990363161210686, -0.04603450713357274, 'nl'),
#   Text(1.0992355702663055, -0.04100196411527794, 'he'),
#   Text(1.0993880184234357, -0.03668766750546649, 'th'),
#   Text(1.0995021239019234, -0.033091985965784415, 'ar'),
#   Text(1.099584941078101, -0.03021518416739545, 'id'),
#   Text(1.0996602312343366, -0.027338175536150495, 'ro'),
#   Text(1.099727993855245, -0.024460979766119193, 'ta'),
#   Text(1.0997882284769684, -0.02158361655264929, 'cs'),
#   Text(1.0998284639438185, -0.01942549610642471, 'af'),
#   Text(1.0998529348820232, -0.01798670707495573, 'ps'),
#   Text(1.0998755236058106, -0.01654788726224571, 'pl'),
#   Text(1.0998962300765243, -0.01510903913059323, 'xx'),
#   Text(1.0999150542587282, -0.013670165142345335, 'tr'),
#   Text(1.0999319961202083, -0.012231267759896247, 'nb'),
#   Text(1.0999470556319713, -0.01079234944567632, 'sl'),
#   Text(1.099960232768245, -0.00935341266215563, 'te'),
#   Text(1.0999715275064792, -0.007914459871831963, 'is'),
#   Text(1.0999809398273452, -0.006475493537234394, 'no'),
#   Text(1.0999884697147349, -0.005036516120911278, 'hu'),
#   Text(1.0999941171557621, -0.0035975300854338356, 'el'),
#   Text(1.0999978821407626, -0.0021585378933851127, 'ky'),
#   Text(1.0999997646632929, -0.0007195420073586872, 'vi')])

# %%
total_por_lingua = tmdb["original_language"].value_counts()
total_por_lingua.loc["en"]
# Out:
# 4505

# %%
total_por_lingua = tmdb["original_language"].value_counts()
total_geral = total_por_lingua.sum()
total_de_ingles = total_por_lingua.loc["en"]
total_do_resto = total_geral - total_de_ingles
print(total_de_ingles, total_do_resto)
# Out:
# 4505 298

# %%
dados = {'lingua' : ['ingles','outros'],'total' : [total_de_ingles, total_do_resto]}

dados = pd.DataFrame(dados)
dados
# Out:
#    lingua  total
# 0  ingles   4505
# 1  outros    298

# %%
sns.barplot(data = dados, x = 'lingua', y = 'total')

# %%
tmdb.query("original_language == 'en'")
# Out:
#          budget  ... vote_count
# 0     237000000  ...      11800
# 1     300000000  ...       4500
# 2     245000000  ...       4466
# 3     250000000  ...       9106
# 4     260000000  ...       2124
# ...         ...  ...        ...
# 4797          0  ...          2
# 4799       9000  ...          5
# 4800          0  ...          6
# 4801          0  ...          7
# 4802          0  ...         16
#
# [4505 rows x 20 columns]

# %%
filmes_sem_lingua_original_em_ingles = tmdb.query("original_language != 'en'")

# %%
total_por_lingua_de_outros_filmes = tmdb.query("original_language != 'en'").original_language.value_counts()

# %%
plt.figure(figsize=(5,10))

sns.catplot(x = "original_language", 
            data = filmes_sem_lingua_original_em_ingles, 
            kind="count",
            aspect=2,
            palette="GnBu_d",
            order = total_por_lingua_de_outros_filmes.index)

# %%
import seaborn as sns
sns.set(style="ticks")

# Load the example dataset for Anscombe's quartet
df = sns.load_dataset("anscombe")

# Show the results of a linear regression within each dataset
sns.lmplot(x="x", y="y", col="dataset", hue="dataset", data=df,
           col_wrap=2, ci=None, palette="muted", height=4,
           scatter_kws={"s": 50, "alpha": 1})

# %% [markdown]
# #Estatística básica

# %%
notas.head(2)
# Out:
#    usuarioId  filmeId  nota    momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247

# %%
notas_do_toy_story = notas.query("filmeId==1")
notas_do_jumanji = notas.query("filmeId==2")
print(len(notas_do_toy_story), len(notas_do_jumanji))
print(notas_do_toy_story, notas_do_jumanji)
# Out:
# 215 110
#        usuarioId  filmeId  nota     momento
# 0              1        1   4.0   964982703
# 516            5        1   4.0   847434962
# 874            7        1   4.5  1106635946
# 1434          15        1   2.5  1510577970
# 1667          17        1   4.5  1305696483
# ...          ...      ...   ...         ...
# 97364        606        1   2.5  1349082950
# 98479        607        1   4.0   964744033
# 98666        608        1   2.5  1117408267
# 99497        609        1   3.0   847221025
# 99534        610        1   5.0  1479542900
#
# [215 rows x 4 columns]        usuarioId  filmeId  nota     momento
# 560            6        2   4.0   845553522
# 1026           8        2   4.0   839463806
# 1773          18        2   3.0  1455617462
# 2275          19        2   3.0   965704331
# 2977          20        2   3.0  1054038313
# ...          ...      ...   ...         ...
# 95102        600        2   4.0  1237764627
# 95965        602        2   4.0   840875851
# 97044        604        2   5.0   832080293
# 97144        605        2   3.5  1277176522
# 98667        608        2   2.0  1117490786
#
# [110 rows x 4 columns]

# %%
print("Nota média do Toy Story %.2f" % notas_do_toy_story.nota.mean())
print("Nota média do Jumanji %.2f" % notas_do_jumanji.nota.mean())

print(notas_do_toy_story.nota.std(), notas_do_jumanji.nota.std())
# Out:
# Nota média do Toy Story 3.92
# Nota média do Jumanji 3.43
# 0.8348591407114045 0.8817134921476455

# %%
print("Nota mediana do Toy Story %.2f" % notas_do_toy_story.nota.median())
print("Nota mediana do Jumanji %.2f" % notas_do_jumanji.nota.median())
# Out:
# Nota mediana do Toy Story 4.00
# Nota mediana do Jumanji 3.50

# %%
import numpy as np

filme1 = np.append(np.array([2.5] * 10), np.array([3.5] * 10))
filme2 = np.append(np.array([5] * 10), np.array([1] * 10))

# %%
print(filme1.mean(), filme2.mean())
print(np.std(filme1), np.std(filme2))
print(np.median(filme1), np.median(filme2))
# Out:
# 3.0 3.0
# 0.5 2.0
# 3.0 3.0

# %%
plt.hist(filme1)
plt.hist(filme2)
# Out:
# (array([10.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0., 10.]),
#  array([1. , 1.4, 1.8, 2.2, 2.6, 3. , 3.4, 3.8, 4.2, 4.6, 5. ]),
#  <a list of 10 Patch objects>)

# %%
plt.boxplot([filme1, filme2])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7fce9cbdcbd0>,
#   <matplotlib.lines.Line2D at 0x7fce9cbc8190>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fce9cbd6c10>,
#   <matplotlib.lines.Line2D at 0x7fce9cbcf190>,
#   <matplotlib.lines.Line2D at 0x7fce9cbbf0d0>,
#   <matplotlib.lines.Line2D at 0x7fce9cbbf5d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fce9cbcfc50>,
#   <matplotlib.lines.Line2D at 0x7fce9cbbffd0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7fce9cbcf710>,
#   <matplotlib.lines.Line2D at 0x7fce9cbbfad0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fce9cbd6190>,
#   <matplotlib.lines.Line2D at 0x7fce9cbd66d0>,
#   <matplotlib.lines.Line2D at 0x7fce9cbc86d0>,
#   <matplotlib.lines.Line2D at 0x7fce9cbc8b90>]}

# %%
import seaborn as sns

sns.boxplot(x=notas_do_jumanji.filmeId, y=notas_do_jumanji.nota, hue=None, data=notas_do_toy_story, order=None, hue_order=None, orient=None, color=None, palette=None, saturation=0.75, width=0.8, dodge=True, fliersize=5, linewidth=None, whis=1.5, ax=None)

# %%
sns.boxplot(x=notas_do_toy_story.filmeId, y=notas_do_toy_story.nota, hue=None, data=notas_do_toy_story, order=None, hue_order=None, orient=None, color=None, palette=None, saturation=0.75, width=0.8, dodge=True, fliersize=5, linewidth=None, whis=1.5, ax=None)

# %%
import matplotlib.pyplot as plt

plt.boxplot([notas_do_toy_story.nota,notas_do_jumanji.nota])
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# {'boxes': [<matplotlib.lines.Line2D at 0x7fce7e4a8390>,
#   <matplotlib.lines.Line2D at 0x7fce7e4b6950>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fce7e4ae3d0>,
#   <matplotlib.lines.Line2D at 0x7fce7e4ae910>,
#   <matplotlib.lines.Line2D at 0x7fce7e4be850>,
#   <matplotlib.lines.Line2D at 0x7fce7e4bed50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fce7e4b6410>,
#   <matplotlib.lines.Line2D at 0x7fce7e4c7790>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7fce7e4aee90>,
#   <matplotlib.lines.Line2D at 0x7fce7e4c7290>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fce7e4a8910>,
#   <matplotlib.lines.Line2D at 0x7fce7e4a8e50>,
#   <matplotlib.lines.Line2D at 0x7fce7e4b6e50>,
#   <matplotlib.lines.Line2D at 0x7fce7e4be350>]}

# %% [markdown]
# #opção
